# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### OpenAI Client

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5.6-luna",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# 1. Lantern
# 2. Meadow
# 3. Whisper
# 4. Velvet
# 5. Compass
# 6. Thunder
# 7. Orchard
# 8. Marble
# 9. Sparrow
# 10. Eclipse

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=62, prompt_tokens=24, total_tokens=86, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=14, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cache_write_tokens=0, cached_tokens=0))

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5.6-luna",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="low"
)

print(response.choices[0].message.content)
# Out:
# Lantern
# Meadow
# Quasar
# Pebble
# Velvet
# Cactus
# Whisper
# Orbit
# Mosaic
# Thunder

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5.6-luna",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="none"
)

print(response.choices[0].message.content)
# Out:
# Lantern, meadow, cobalt, whisper, tumble, orchard, velvet, compass, thunder, mosaic

# %% [markdown]
# ### Groq Client
